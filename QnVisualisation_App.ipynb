# %%
import streamlit as st

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/PycharmProjects/CourseNL/venv/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     359             # Hash the input
# --> 360             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     361
#
# ~/PycharmProjects/CourseNL/venv/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     625             assert code is not None
# --> 626             if self._file_should_be_hashed(code.co_filename):
#     627                 context = _get_context(obj)
#
# ~/PycharmProjects/CourseNL/venv/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     401         return file_util.file_is_in_folder_glob(
# ...
